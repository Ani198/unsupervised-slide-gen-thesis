# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
from nltk import sent_tokenize
from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from tqdm import tqdm
import random
import json

# %%
dataset = pd.read_csv('../data/papers_dataset.csv')
dataset.keywords = dataset.keywords.apply(ast.literal_eval)
dataset.sections = dataset.sections.apply(ast.literal_eval)

with open('../data/categories.json', 'r') as f:
    categ_id = json.load(f)

test_df = dataset[dataset.partition == 'test']

sentences_list = []

for _, row in test_df.iterrows():
    all_sentences = []
    abstract_sents = sent_tokenize(row['abstract'])
    all_sentences += abstract_sents
    
    for section in row['sections'].values():
        section_sents = sent_tokenize(section)
        all_sentences += section_sents
        
    sentences_list.append(all_sentences)
    
test_df['sentences'] = sentences_list
# Out:
# C:\Users\User\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_parts = []
for i in tqdm(range(5)):
    data = pd.read_csv(f'../data/sentence_embeddings_{(i+1)*100}.csv')
    data_parts.append(data)
    
data_df = pd.concat(data_parts, axis = 0)
data_df.sent_tr_emb = data_df.sent_tr_emb.apply(lambda x: list(np.fromstring(x[1:-1],sep=' ').astype(float)))
data_df['categ_id'] = [categ_id[i] for i in data_df.category.values]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:09<00:00,  1.92s/it]

# %%
data_df.shape
# Out:
# (68777, 5)

# %%
data_df.head()
# Out:
#                                                title                 category  \
# 0  A Comprehensive Review on Heart Disease Predic...  Artificial Intelligence
# 1  A Comprehensive Review on Heart Disease Predic...  Artificial Intelligence
# 2  A Comprehensive Review on Heart Disease Predic...  Artificial Intelligence
# 3  A Comprehensive Review on Heart Disease Predic...  Artificial Intelligence
# 4  A Comprehensive Review on Heart Disease Predic...  Artificial Intelligence
#
#                                             sentence  categ_id  \
# 0  Heart disease is one of the major causes of li...         0
# 1  The heart disease diagnosis and treatment are ...         0
# 2  Inadequate preventive measures, lack of experi...         0
# 3  Although, large proportion of heart diseases i...         0
# 4  In today's digital world, several clinical dec...         0
#
#                                          sent_tr_emb
# 0  [0.4460226, -0.845141947, 0.146280348, -1.1929...
# 1  [-0.18601216, -0.037789, 0.09992175, 0.1720532...
# 2  [-0.231186911, -0.189537778, 0.0427042805, -0....
# 3  [0.16552189, -0.309478015, 0.113730304, -0.397...
# 4  [0.10223487, -0.170204878, 0.340327203, -0.030...

# %%
test_papers = set(test_df.title.values)
len(test_papers)
# Out:
# 36

# %%
data_df = data_df[data_df.title.isin(test_papers)]
data_df.shape
# Out:
# (4173, 5)

# %%
len(data_df.title.value_counts())
# Out:
# 36

# %%
type(data_df.sent_tr_emb.iloc[0])
# Out:
# list

# %%
sent_emb_dict = dict(zip(data_df.sentence.values, data_df.sent_tr_emb.values))

# %%
sentence_embeddings = []

def get_sent_transf_emb(paper_text, emb_df):
    sentence_embeddings = [sent_emb_dict[sentence] for sentence in paper_text]

# %%
test_df['sentence_embeddings'] = test_df.sentences.apply(lambda x: [sent_emb_dict[sentence] for sentence in x])
# Out:
# C:\Users\User\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_df
# Out:
#       paper_id                             category  \
# 1      paper_1              Artificial Intelligence
# 2      paper_2              Artificial Intelligence
# 3      paper_3              Artificial Intelligence
# 21    paper_21      Computer Science and Technology
# 31    paper_31      Computer Science and Technology
# 38    paper_38      Computer Science and Technology
# 57    paper_57      Control and Intelligent Systems
# 78    paper_78      Control and Intelligent Systems
# 96    paper_96      Control and Intelligent Systems
# 134  paper_134  Data Mining and Knowledge Discovery
# 139  paper_139  Data Mining and Knowledge Discovery
# 145  paper_145  Data Mining and Knowledge Discovery
# 212  paper_212            Data Science and Analysis
# 214  paper_214            Data Science and Analysis
# 216  paper_216            Data Science and Analysis
# 219  paper_219          Data Science and Technology
# 241  paper_241          Data Science and Technology
# 251  paper_251          Data Science and Technology
# 272  paper_272   Information Science and Technology
# 294  paper_294   Information Science and Technology
# 298  paper_298   Information Science and Technology
# 305  paper_305      Intelligent Information Systems
# 310  paper_310      Intelligent Information Systems
# 333  paper_333      Intelligent Information Systems
# 389  paper_389            Machine Learning Research
# 391  paper_391            Machine Learning Research
# 402  paper_402            Machine Learning Research
# 418  paper_418  Mathematical and Computer Modelling
# 428  paper_428  Mathematical and Computer Modelling
# 432  paper_432  Mathematical and Computer Modelling
# 444  paper_444     Mathematics and Computer Science
# 462  paper_462     Mathematics and Computer Science
# 476  paper_476     Mathematics and Computer Science
# 479  paper_479     Neural Networks and Applications
# 492  paper_492     Neural Networks and Applications
# 507  paper_507     Neural Networks and Applications
#
#                                                   name  num_pages  \
# 1    A Model for Clustering Social Media Data for E...          4
# 2    An Intelligent System for Traffic Control in S...          8
# 3    Architecture Trends of Adaptive Educational Hy...         14
# 21   A New Powerful Scheme Based on Self Invertible...          5
# 31   Design and Implementation of Intelligent Medic...          6
# 38   Predicting Students’ First-Year Academic Perfo...         13
# 57   Ant Colony Optimization with Genetic Operation...          6
# 78   Fuzzy C-means Clustering Applied to the Classi...          5
# 96   On the Warning System of Obstacle Avoidance of...          4
# 134  Data Mining Technique Used in Order to Analysi...          6
# 139  Extermination of Obsolete Relationship Through...          5
# 145  Level of Obesity and Socioeconomic Factors of ...          7
# 212  The Modeling of a Stochastic SIR Model for HIV...          6
# 214  Using Databases in Decisions Systems for Busin...          6
# 216  Valuation of European Call Options Using Wavel...          7
# 219  A Framework for Evaluating Data Quality on Mil...          8
# 241  Digital Differential Current Protection Scheme...          5
# 251  Multiple Agents Based Scheduling and Monitorin...          5
# 272  Analysis of Parameters and Time Sequences for ...          7
# 294  The Impact of Public Libraries on Tiv Manageme...          7
# 298  Users Attitude Towards the Use of Library Cata...          7
# 305  An Application of the Logitboost Ensemble Algo...          6
# 310  Android Application Based Bluetooth Controlled...          5
# 333  Ethiopian Enset Diseases Diagnosis Model Using...          5
# 389  Chinese Word Segmentation Based on Conditional...          5
# 391  Data Mining of Access to Tetanus Toxoid Immuni...          7
# 402  Learning Algorithms Using BPNN & SFS for Predi...          6
# 418  A Comparative Study on Additive and Mixed Mode...          6
# 428  Mixed Convective Magnetohydrodynamic Heat Tran...          8
# 432  On Cotangent Bundles Hamiltonian Tubes Theorem...          5
# 444  An Uncertain Resource Constrained Scheduling M...          4
# 462  Innovation and Practice of the Training Model ...          8
# 476  The Relationship of Delivery Frequency with th...         12
# 479  A Neural Network Approach to Writer’s Model fo...          7
# 492  Each Role of Short-term and Long-term Memory i...          6
# 507  Study and Prediction of Landslide in Uttarkash...         12
#
#      num_formulas  num_figures  \
# 1               0            4
# 2               5            9
# 3               0           12
# 21              1            2
# 31              2           10
# 38              1           11
# 57              6           15
# 78              8            2
# 96              0            1
# 134             0            7
# 139             0           16
# 145             0           11
# 212             2            4
# 214             0            4
# 216             6           14
# 219             6            5
# 241             0            5
# 251             0            6
# 272             1           13
# 294             0            4
# 298             0            8
# 305             0            4
# 310             0            9
# 333             0            6
# 389             1            6
# 391             0            9
# 402             0           13
# 418             7           10
# 428             0           17
# 432             8            8
# 444             9            2
# 462             0            1
# 476             0           23
# 479             6            6
# 492             1            7
# 507             1           21
#
#                                                  title  \
# 1    A Model for Clustering Social Media Data for E...
# 2    An Intelligent System for Traffic Control in S...
# 3    Architecture Trends of Adaptive Educational Hy...
# 21   A New Powerful Scheme Based on Self Invertible...
# 31   Design and Implementation of Intelligent Medic...
# 38   Predicting Students' First-Year Academic Perfo...
# 57     Ant colony optimization with genetic operations
# 78   Fuzzy C-means Clustering Applied to the Classi...
# 96   On the warning system of obstacle avoidance of...
# 134  Data Mining Technique Used in Order to Analysi...
# 139  Extermination of Obsolete Relationship Through...
# 145  Level of Obesity and Socioeconomic Factors of ...
# 212  The Modeling of a Stochastic SIR Model for HIV...
# 214  Using Databases in Decisions Systems for Busin...
# 216  Valuation of European Call Options Using Wavel...
# 219  A Framework for Evaluating Data Quality on Mil...
# 241  Digital Differential Current Protection Scheme...
# 251  Multiple Agents Based Scheduling and Monitorin...
# 272  Analysis of Parameters and Time Sequences for ...
# 294  The Impact of Public Libraries on Tiv Manageme...
# 298  Users Attitude Towards the Use of Library Cata...
# 305  An application of the logitboost ensemble algo...
# 310  Android Application Based Bluetooth Controlled...
# 333  Ethiopian Enset Diseases Diagnosis Model Using...
# 389  Chinese Word Segmentation Based on Conditional...
# 391  Data Mining of Access to Tetanus Toxoid Immuni...
# 402  Learning Algorithms Using BPNN & SFS for Predi...
# 418  A Comparative Study on Additive and Mixed Mode...
# 428  Mixed Convective Magnetohydrodynamic Heat Tran...
# 432  On Cotangent Bundles Hamiltonian Tubes Theorem...
# 444  An Uncertain Resource Constrained Scheduling M...
# 462  Innovation and Practice of the Training Model ...
# 476  The Relationship of Delivery Frequency with th...
# 479  A Neural Network Approach to Writer's Model fo...
# 492  Each Role of Short-term and Long-term Memory i...
# 507  Study and Prediction of Landslide in Uttarkash...
#
#                                               keywords  \
# 1    [Social Media, Twitter Application Programming...
# 2    [Smart Cities, Traffic Congestion, Intelligent...
# 3    [Adaptive Educational Hypermedia Systems, Arch...
# 21   [Minimum Distance, Minimum Weight, BCH Codes, ...
# 31     [Smart Medical Care, ZigBee, Semantic Matching]
# 38   [Ordinary Level, Unified Tertiary Matriculatio...
# 57   [Ant Colony Optimization, Genetic Operations, ...
# 78   [Fuzzy Set Theory, Numerical Classification, L...
# 96   [Embedded System, Electronic Guide Dog, Avoidi...
# 134  [Data Mining, Regression, Olive Oil, Authentic...
# 139  [Data Mining, Degree, Maximum Degree, Minimum ...
# 145  [Obesity Among Adult People, Socioeconomic Fac...
# 212  [Stochastic, Simulation, Deterministic, SIR Mo...
# 214  [Business Intelligence Tools, Datawarehouse St...
# 216         [Options, Wavelet Model, Derivatives, MGF]
# 219  [Data Quality, Data Relevance, Quality of Data...
# 241  [Transformers, Differential Current Protection...
# 251  [Grid, Cloud, Utility Computing, IaaS, SaaS, P...
# 272  [Parameters of Switching Processing Times, Alc...
# 294  [Tiv Management of Postharvest Losses, Posthar...
# 298  [Card Catalogue, Information Resources, Librar...
# 305  [LogitBoost, Loan Appraising, LDA, Ensemble Le...
# 310  [Wireless, Android, Bluetooth, Arduino, Roboti...
# 333  [Multiclass SVM, Kernels, Enset Disease, K-mea...
# 389  [Natural Language Processing, Chinese Word Seg...
# 391  [Data Mining, WEKA, Classification, Clustering...
# 402  [ANN, SFS, UHPC, Compressive Strength, Constit...
# 418  [Buys-Ballot Table, Time Series Decomposition,...
# 428  [Williamson Fluid, Boundary Layer Flow, Mixed ...
# 432  [Reduction, Cotangent Bundles, Hamiltonian Tub...
# 444  [Project Schedule Problem, Uncertainty Theory,...
# 462  [Clinical Medicine, Master, Professional Degre...
# 476  [Delivery Frequency, Delivery Cost, Delivery R...
# 479  [L R, BPNN, Handwriting, Nuisance Parameter, F...
# 492  [Short-term Memory, Long-term Memory, Serial P...
# 507  [India, Uttarkashi, Landslide Susceptibility, ...
#
#                                               abstract  \
# 1    Through Social media, people are able to write...
# 2    Current traffic light systems use a fixed time...
# 3    The aim of this article is to present the gene...
# 21   In this paper, we present the powerful scheme ...
# 31   With the continuous improvement of human livin...
# 38   The study aimed to determine if any of the ent...
# 57   This paper attempts to overcome stagnation pro...
# 78   Fuzzy C-means clustering is a soft technique a...
# 96   With the rapid development of China's transpor...
# 134  Data mining, also referred to as knowledge ext...
# 139  At the present time web contains many indistin...
# 145  The present study was based on data collected ...
# 212  Mathematical modeling of disease has been an i...
# 214  The paper presents the usage of databases that...
# 216  The Black-Scholes model is a well-known model ...
# 219  This paper introduces a framework to determine...
# 241  Transformers are the key equipment in electric...
# 251  Cloud computing is associated with a new parad...
# 272  Parameters of a vacuum interrupter are essenti...
# 294  The cultural heritage of any people can be red...
# 298  The study investigated the awareness and use o...
# 305  Mitigation of credit risk is a key aspect of p...
# 310  We are now living in the 21 st century. Now, s...
# 333  The diagnosis of diseases on the plant is a ve...
# 389  This paper systematically describes the defini...
# 391  Tetanus toxoid (TT) vaccine is given to women ...
# 402  This paper presents machine learning algorithm...
# 418  Time series analyses are statistical methods u...
# 428  The present article examines the influence of ...
# 432  This paper aims to study the Cotangent Bundles...
# 444  Resource constrained project scheduling proble...
# 462  To deepen the reform of clinical medical perso...
# 476  Under drastic competition, major express compa...
# 479  Handwriting is an integral part of our life th...
# 492  Based on known functions of neuroscience the n...
# 507  Landslide is defined as a slow to rapid downwa...
#
#                                               sections  num_sentences  \
# 1    {'Introduction': 'Clustering is a descriptive ...             76
# 2    {'Introduction': '', 'Background': 'Traffic co...             99
# 3    {'Introduction': 'Adaptive Hypermedia Educatio...            203
# 21   {'Introduction': 'In telecommunication and sto...             60
# 31   {'Introduction': 'From 1990 to 2017, the morbi...            124
# 38   {'Introduction': 'Education is an essential is...            186
# 57   {'Introduction': 'Wide range of problems like ...            131
# 78   {'Introduction': 'Quantitative methods, such a...            126
# 96   {'Introduction': 'During last summer, I went b...             68
# 134  {'Introduction': 'New information and communic...            103
# 139  {'Introduction': 'The data and information ava...             45
# 145  {'Introduction': 'The prevalence of overweight...            160
# 212  {'Introduction': 'On June 5, 1981 a mysterious...            136
# 214  {'Introduction': 'Objectives of decision-makin...            119
# 216  {'Introduction': 'The financial contracts or i...             99
# 219  {'Introduction': 'To achieve information domin...            199
# 241  {'Introduction': 'The demand of electricity in...             50
# 251  {'Introduction': 'Heterogeneity in the computa...            110
# 272  {'Introduction': 'Since many years up to date ...             68
# 294  {'Introduction': 'The cultural heritage of any...            151
# 298  {'Introduction': 'The university library goals...            135
# 305  {'Introduction': 'Loans constitute the corners...            149
# 310  {'Introduction': 'This paper represents androi...            112
# 333  {'Introduction': 'Food security is a challenge...             62
# 389  {'Introduction': '', 'Annotation Method': 'The...             76
# 391  {'Introduction': 'Tetanus toxoid (TT) vaccine ...            149
# 402  {'Introduction': 'Several types of machine lea...             91
# 418  {'Introduction': 'An important goal in time se...             72
# 428  {'Introduction': 'The theory of non-Newtonian ...             88
# 432  {'Introduction': 'The Cotangent Bundles * of m...             89
# 444  {'Introduction': 'The resource constrained pro...             91
# 462  {'Introduction': 'Chongqing Medical University...            171
# 476  {'Introduction': 'As the volume of orders and ...            164
# 479  {'Introduction': 'Handwriting has remained one...            108
# 492  {'Introduction': 'If you look back at the huma...            175
# 507  {'Introduction': 'A frequently used definition...            128
#
#      sent_by_page partition  \
# 1       25.333333      test
# 2       14.142857      test
# 3       15.615385      test
# 21      15.000000      test
# 31      24.800000      test
# 38      15.500000      test
# 57      26.200000      test
# 78      31.500000      test
# 96      22.666667      test
# 134     20.600000      test
# 139     11.250000      test
# 145     26.666667      test
# 212     27.200000      test
# 214     23.800000      test
# 216     16.500000      test
# 219     28.428571      test
# 241     12.500000      test
# 251     27.500000      test
# 272     11.333333      test
# 294     25.166667      test
# 298     22.500000      test
# 305     29.800000      test
# 310     28.000000      test
# 333     15.500000      test
# 389     19.000000      test
# 391     24.833333      test
# 402     18.200000      test
# 418     14.400000      test
# 428     12.571429      test
# 432     22.250000      test
# 444     30.333333      test
# 462     24.428571      test
# 476     14.909091      test
# 479     18.000000      test
# 492     35.000000      test
# 507     11.636364      test
#
#                                              sentences  \
# 1    [Through Social media, people are able to writ...
# 2    [Current traffic light systems use a fixed tim...
# 3    [The aim of this article is to present the gen...
# 21   [In this paper, we present the powerful scheme...
# 31   [With the continuous improvement of human livi...
# 38   [The study aimed to determine if any of the en...
# 57   [This paper attempts to overcome stagnation pr...
# 78   [Fuzzy C-means clustering is a soft technique ...
# 96   [With the rapid development of China's transpo...
# 134  [Data mining, also referred to as knowledge ex...
# 139  [At the present time web contains many indisti...
# 145  [The present study was based on data collected...
# 212  [Mathematical modeling of disease has been an ...
# 214  [The paper presents the usage of databases tha...
# 216  [The Black-Scholes model is a well-known model...
# 219  [This paper introduces a framework to determin...
# 241  [Transformers are the key equipment in electri...
# 251  [Cloud computing is associated with a new para...
# 272  [Parameters of a vacuum interrupter are essent...
# 294  [The cultural heritage of any people can be re...
# 298  [The study investigated the awareness and use ...
# 305  [Mitigation of credit risk is a key aspect of ...
# 310  [We are now living in the 21 st century., Now,...
# 333  [The diagnosis of diseases on the plant is a v...
# 389  [This paper systematically describes the defin...
# 391  [Tetanus toxoid (TT) vaccine is given to women...
# 402  [This paper presents machine learning algorith...
# 418  [Time series analyses are statistical methods ...
# 428  [The present article examines the influence of...
# 432  [This paper aims to study the Cotangent Bundle...
# 444  [Resource constrained project scheduling probl...
# 462  [To deepen the reform of clinical medical pers...
# 476  [Under drastic competition, major express comp...
# 479  [Handwriting is an integral part of our life t...
# 492  [Based on known functions of neuroscience the ...
# 507  [Landslide is defined as a slow to rapid downw...
#
#                                    sentence_embeddings
# 1    [[0.992317319, 0.0893145874, -0.340903342, -0....
# 2    [[-0.375607759, -0.0790585652, 0.888247252, -0...
# 3    [[-0.564446807, 0.879449368, 0.720221996, -0.5...
# 21   [[-0.848686039, 0.408086479, 0.431638807, 0.30...
# 31   [[0.154241785, 0.48725009, 0.497481078, -1.171...
# 38   [[0.0349662565, 0.540855408, 0.477420688, -0.3...
# 57   [[-0.762145102, 0.363119364, 0.133871302, -0.7...
# 78   [[-1.2003119, -0.327789366, 0.26096487, -0.069...
# 96   [[-0.356183827, -0.418222368, 0.153359815, -0....
# 134  [[-0.0839086249, 0.508139968, 0.204696253, 0.5...
# 139  [[-0.241933316, -0.753845394, -0.139548525, 0....
# 145  [[0.497778028, -0.322578192, 0.319347292, 0.82...
# 212  [[-0.808155715, -0.313350976, -0.122795656, 0....
# 214  [[0.0133612119, 0.726706803, -0.100927405, -0....
# 216  [[0.223053232, -0.326895714, -0.588464081, 0.0...
# 219  [[-0.109534495, 0.0437600762, -0.311325639, -0...
# 241  [[1.022066, -0.588377893, 0.533178747, 0.41105...
# 251  [[-0.5876671, -0.04192317, 0.61136425, -0.9380...
# 272  [[-0.643186748, 0.0654180124, -0.11557544, 0.2...
# 294  [[-0.356746107, 0.189799547, -0.203986853, 0.3...
# 298  [[0.194673762, 0.561683357, 0.295757324, -0.16...
# 305  [[-0.774092317, -0.481371701, -0.635278642, -0...
# 310  [[0.245638952, -0.0737744197, 0.159693986, -0....
# 333  [[-0.627675176, -0.251061499, -0.286780477, 0....
# 389  [[-0.378287107, 0.0222173203, -0.409629613, 0....
# 391  [[0.51769084, -0.50691515, -0.83278555, -0.069...
# 402  [[0.221574843, 0.457796365, 0.742292106, -0.09...
# 418  [[1.00532818, -0.324459851, 0.562639773, -0.01...
# 428  [[0.0760288686, -0.919789195, 0.491262764, 0.0...
# 432  [[-0.6377146, 0.08161658, 0.5858777, -0.123802...
# 444  [[-0.12263833, 0.17453098, -0.10217835, -0.492...
# 462  [[-0.174294338, -0.0506502874, 0.638741016, -0...
# 476  [[0.517397523, 0.190035284, -0.39375028, -0.57...
# 479  [[0.324848711, -0.0939144492, -0.547561347, 0....
# 492  [[0.483206362, -0.42199707, 0.975736439, -0.31...
# 507  [[-0.624056876, -0.278606564, 0.836973429, 0.1...

# %%
test_df.to_csv('./test_papers_sent_transf.csv', index = False)
